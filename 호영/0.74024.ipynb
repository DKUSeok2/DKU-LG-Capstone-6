# %% [markdown]
# ### Import

# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import seaborn as sns

# 각 라이브러리 버전 출력
print("Numpy version:", np.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# Numpy version: 1.26.4
# Scikit-learn version: 1.4.2
# Pandas version: 2.2.2
# Matplotlib version: 3.8.4
# Seaborn version: 0.13.2

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import  OrdinalEncoder
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# ### Data Load

# %%
import sys
import os
import pandas as pd

# 현재 작업 디렉토리 경로를 가져와 shared codes 폴더의 위치를 sys.path에 추가합니다.
# sys.path에 추가된 경로에 있는 py 폴더는 임포트할 수 있다.
current_dir = os.getcwd()
shared_codes_dir = os.path.join(current_dir, '../shared codes')
sys.path.append(shared_codes_dir)


# cover_nan 모듈을 임포트
from cover_nan import missing_value_removal_function

# 원본 train 데이터 로드
train = pd.read_csv("../shared codes/data/train.csv").drop(columns=['ID'])
test = pd.read_csv("../shared codes/data/test.csv").drop(columns=['ID'])

# missing_value_removal_function 사용
train = missing_value_removal_function(train)
test = missing_value_removal_function(test)
# Out:
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부']
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부']
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:97: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['난자 출처'].replace('알 수 없음','본인 제공', inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:103: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['파트너 정자와 혼합된 난자 수'].fillna(0, inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['기증자 정자와 혼합된 난자 수'].fillna(1, inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:110: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(0, inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:97: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['난자 출처'].replace('알 수 없음','본인 제공', inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:103: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['파트너 정자와 혼합된 난자 수'].fillna(0, inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:106: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['기증자 정자와 혼합된 난자 수'].fillna(1, inplace=True)
# c:\Users\hoyeong\OneDrive - 단국대학교\LG AImers\6기\코드\호영\../shared codes\cover_nan.py:110: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(0, inplace=True)

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
columns_fill_zero = [
    # 'PGD 시술 여부', 'PGS 시술 여부',
    '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부'
]
X[columns_fill_zero] = X[columns_fill_zero].fillna(0)
test[columns_fill_zero] = test[columns_fill_zero].fillna(0)

# %%
X['난자 채취 경과일'].fillna(1, inplace=True)
X['난자 해동 경과일'].fillna(0, inplace=True)
X['난자 혼합 경과일'].fillna(0, inplace=True)
X['배아 이식 경과일'].fillna(0, inplace=True)
X['배아 해동 경과일'].fillna(0, inplace=True)

test['난자 채취 경과일'].fillna(1, inplace=True)
test['난자 해동 경과일'].fillna(0, inplace=True)
test['난자 혼합 경과일'].fillna(0, inplace=True)
test['배아 이식 경과일'].fillna(0, inplace=True)
test['배아 해동 경과일'].fillna(0, inplace=True)

# 병합할 칼럼들
columns_to_merge = [
    '난자 채취 경과일', '난자 해동 경과일', '난자 혼합 경과일',
    '배아 이식 경과일', '배아 해동 경과일'
]

# 새로운 칼럼 생성: 각 경과일의 합
X['총 경과일'] = X[columns_to_merge].sum(axis=1)

# 기존 칼럼 제거
X = X.drop(columns=columns_to_merge)

# 새로운 칼럼 생성: 각 경과일의 합
test['총 경과일'] = test[columns_to_merge].sum(axis=1)

# 기존 칼럼 제거
test = test.drop(columns=columns_to_merge)
# Out:
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['난자 채취 경과일'].fillna(1, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['난자 해동 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['난자 혼합 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['배아 이식 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['배아 해동 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['난자 채취 경과일'].fillna(1, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['난자 해동 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['난자 혼합 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['배아 이식 경과일'].fillna(0, inplace=True)
# C:\Users\hoyeong\AppData\Local\Temp\ipykernel_46736\1085533716.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['배아 해동 경과일'].fillna(0, inplace=True)

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# Series([], dtype: int64)

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('알 수 없음').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ '알 수 없음' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ⚠️ '알 수 없음' 값을 포함하는 컬럼들:
# ['시술 당시 나이', '배란 유도 유형', '난자 기증자 나이', '정자 기증자 나이']

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('nan').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ 'nan' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ⚠️ 'nan' 값을 포함하는 컬럼들:
# []

# %%
# NaN 값이 존재하는 컬럼 찾기
unknown_columns = X.columns[X.isna().any()].tolist()

unknown_columns
# Out:
# []

# %%
# Categorical(범주형) 칼럼 찾기
categorical_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()
for col in categorical_columns:
    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

# 결과 출력
print("📌 Categorical(범주형) 칼럼 리스트:")
print(categorical_columns)
# Out:
# 📌 Categorical(범주형) 칼럼 리스트:
# ['시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', '총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수', 'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '난자 출처', '정자 출처', '난자 기증자 나이', '정자 기증자 나이']

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
columns_to_drop = [
        "남성 주 불임 원인",
        "남성 부 불임 원인",
        "불임 원인 - 정자 농도",
        "불임 원인 - 정자 면역학적 요인",
        "불임 원인 - 정자 운동성",
        "불임 원인 - 정자 형태",
        '정자 기증자 나이',
        '배란 유도 유형'
]
X_train_encoded = X_train_encoded.drop(columns = columns_to_drop)    
X_test_encoded = X_test_encoded.drop(columns = columns_to_drop)

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X_train_encoded.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# Series([], dtype: int64)

# %%
X_train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256351 entries, 0 to 256350
# Data columns (total 52 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   시술 시기 코드          256351 non-null  float64
#  1   시술 당시 나이          256351 non-null  float64
#  2   시술 유형             256351 non-null  float64
#  3   특정 시술 유형          256351 non-null  float64
#  4   배란 자극 여부          256351 non-null  int64
#  5   단일 배아 이식 여부       256351 non-null  float64
#  6   착상 전 유전 검사 사용 여부  256351 non-null  float64
#  7   착상 전 유전 진단 사용 여부  256351 non-null  float64
#  8   여성 주 불임 원인        256351 non-null  int64
#  9   여성 부 불임 원인        256351 non-null  int64
#  10  부부 주 불임 원인        256351 non-null  int64
#  11  부부 부 불임 원인        256351 non-null  int64
#  12  불명확 불임 원인         256351 non-null  int64
#  13  불임 원인 - 난관 질환     256351 non-null  int64
#  14  불임 원인 - 남성 요인     256351 non-null  int64
#  15  불임 원인 - 배란 장애     256351 non-null  int64
#  16  불임 원인 - 여성 요인     256351 non-null  int64
#  17  불임 원인 - 자궁경부 문제   256351 non-null  int64
#  18  불임 원인 - 자궁내막증     256351 non-null  int64
#  19  배아 생성 주요 이유       256351 non-null  int64
#  20  총 시술 횟수           256351 non-null  float64
#  21  클리닉 내 총 시술 횟수     256351 non-null  float64
#  22  IVF 시술 횟수         256351 non-null  float64
#  23  DI 시술 횟수          256351 non-null  float64
#  24  총 임신 횟수           256351 non-null  float64
#  25  IVF 임신 횟수         256351 non-null  float64
#  26  DI 임신 횟수          256351 non-null  float64
#  27  총 출산 횟수           256351 non-null  float64
#  28  IVF 출산 횟수         256351 non-null  float64
#  29  DI 출산 횟수          256351 non-null  float64
#  30  총 생성 배아 수         256351 non-null  float64
#  31  미세주입된 난자 수        256351 non-null  float64
#  32  미세주입에서 생성된 배아 수   256351 non-null  float64
#  33  이식된 배아 수          256351 non-null  float64
#  34  미세주입 배아 이식 수      256351 non-null  float64
#  35  저장된 배아 수          256351 non-null  float64
#  36  미세주입 후 저장된 배아 수   256351 non-null  float64
#  37  해동된 배아 수          256351 non-null  float64
#  38  해동 난자 수           256351 non-null  float64
#  39  수집된 신선 난자 수       256351 non-null  float64
#  40  저장된 신선 난자 수       256351 non-null  float64
#  41  혼합된 난자 수          256351 non-null  float64
#  42  파트너 정자와 혼합된 난자 수  256351 non-null  float64
#  43  기증자 정자와 혼합된 난자 수  256351 non-null  float64
#  44  난자 출처             256351 non-null  float64
#  45  정자 출처             256351 non-null  float64
#  46  난자 기증자 나이         256351 non-null  float64
#  47  동결 배아 사용 여부       256351 non-null  float64
#  48  신선 배아 사용 여부       256351 non-null  float64
#  49  기증 배아 사용 여부       256351 non-null  float64
#  50  대리모 여부            256351 non-null  float64
#  51  총 경과일             256351 non-null  float64
# dtypes: float64(39), int64(13)
# memory usage: 101.7 MB

# %%
X_train_encoded['배아 생성 주요 이유'].value_counts()
# Out:
# 배아 생성 주요 이유
# 1    253108
# 0      3243
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 데이터 정규화 (X_train_encoded & X_test_encoded)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)  # 동일한 스케일 적용

# DataFrame 변환 (Feature 이름 유지)
feature_names = [f"Feature_{i}" for i in range(X_train_scaled.shape[1])]
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=feature_names)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=feature_names)

# 상관 행렬 계산
correlation_matrix_train = X_train_scaled_df.corr()

# 다중 공선성이 높은 칼럼 찾기 (절대 상관 계수가 0.8 이상)
threshold = 0.8
high_corr_features = set()

for i in range(len(feature_names)):
    for j in range(i + 1, len(feature_names)):
        if abs(correlation_matrix_train.iloc[i, j]) > threshold:
            high_corr_features.add(feature_names[j])  # 공선성이 높은 컬럼 추가

# 다중 공선성이 높은 컬럼 제거
X_train_encoded = X_train_scaled_df.drop(columns=high_corr_features, errors='ignore')
X_test_encoded = X_test_scaled_df.drop(columns=high_corr_features, errors='ignore')

# %%
X_train_encoded
# Out:
#         Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0        1.518507  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# 1        1.020975   2.655919   0.158613  -0.962962  -1.836376  -0.543057
# 2        0.025910  -0.935575   0.158613   0.672585   0.544551  -0.543057
# 3       -0.471622  -0.217277   0.158613  -0.962962   0.544551  -0.543057
# 4        0.025910  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# ...           ...        ...        ...        ...        ...        ...
# 256346   1.020975  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# 256347   1.020975   0.501022   0.158613  -0.962962   0.544551  -0.543057
# 256348   0.025910  -0.217277   0.158613  -0.962962   0.544551  -0.543057
# 256349   1.518507   0.501022   0.158613  -0.962962   0.544551  -0.543057
# 256350   0.523442  -0.217277   0.158613   0.672585  -1.836376  -0.543057
#
#         Feature_6  Feature_7  Feature_8  Feature_9  ...  Feature_38  \
# 0       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 1       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 2       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 3       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 4       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# ...           ...        ...        ...        ...  ...         ...
# 256346  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 256347  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 256348  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 256349  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
# 256350  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.066583
#
#         Feature_39  Feature_40  Feature_43  Feature_44  Feature_45  \
# 0        -0.184224   -0.083423   -0.220261    0.256018    0.344047
# 1        -1.000848   -0.083423   -0.220261    0.256018    0.344047
# 2        -0.048121   -0.083423   -0.220261    0.256018    0.344047
# 3        -0.456432   -0.083423   -0.220261    0.256018    0.344047
# 4        -0.184224   -0.083423   -0.220261    0.256018    0.344047
# ...            ...         ...         ...         ...         ...
# 256346    0.360191   -0.083423   -0.220261    0.256018    0.344047
# 256347   -0.456432   -0.083423   -0.220261    0.256018    0.344047
# 256348    0.224087   -0.083423   -0.220261    0.256018    0.344047
# 256349   -0.728640   -0.083423   -0.220261    0.256018    0.344047
# 256350   -1.136951   -0.083423   -0.220261    0.256018    0.344047
#
#         Feature_47  Feature_49  Feature_50  Feature_51
# 0        -0.430784   -0.098393     -0.0641    0.033850
# 1        -0.430784   -0.098393     -0.0641   -1.586105
# 2        -0.430784   -0.098393     -0.0641   -0.506135
# 3        -0.430784   -0.098393     -0.0641   -1.586105
# 4        -0.430784   -0.098393     -0.0641    0.033850
# ...            ...         ...         ...         ...
# 256346   -0.430784   -0.098393     -0.0641    1.113821
# 256347   -0.430784   -0.098393     -0.0641    0.033850
# 256348   -0.430784   -0.098393     -0.0641    0.033850
# 256349   -0.430784   -0.098393     -0.0641   -1.046120
# 256350    2.321347   -0.098393     -0.0641   -1.046120
#
# [256351 rows x 41 columns]

# %% [markdown]
# ### Train

# %%
model = ExtraTreesClassifier(random_state=42)

model.fit(X_train_encoded, y)
# Out:
# ExtraTreesClassifier(random_state=42)

# %% [markdown]
# **앙상블 및 Optuna**

# %%
import optuna
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np

# %%
def optimize_xgboost(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5)
    }
    model = XGBClassifier(**params, random_state=42, use_label_encoder=False, eval_metric="logloss")
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")
    return np.mean(scores)

# %%
def optimize_lightgbm(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 10, 50),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0)
    }
    model = LGBMClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
def optimize_random_forest(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_samples_split": trial.suggest_int("min_samples_split", 3, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 4)
    }
    model = RandomForestClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
# Optuna 스터디 실행
print("Optimizing XGBoost...")
xgb_study = optuna.create_study(direction="maximize")
xgb_study.optimize(optimize_xgboost, n_trials=30)
best_xgb_params = xgb_study.best_params

print("Optimizing LightGBM...")
lgbm_study = optuna.create_study(direction="maximize")
lgbm_study.optimize(optimize_lightgbm, n_trials=30)
best_lgbm_params = lgbm_study.best_params

print("Optimizing RandomForest...")
rf_study = optuna.create_study(direction="maximize")
rf_study.optimize(optimize_random_forest, n_trials=30)
best_rf_params = rf_study.best_params
# Out:
# [I 2025-02-16 20:16:10,036] A new study created in memory with name: no-name-95c7c364-0845-496d-b8da-4dd71d771b19
# Optimizing XGBoost...
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:14,518] Trial 0 finished with value: 0.7384164492634121 and parameters: {'n_estimators': 161, 'max_depth': 3, 'learning_rate': 0.20162463020240848, 'subsample': 0.8594484079202798, 'colsample_bytree': 0.7820553779644607, 'gamma': 0.06796926397576675}. Best is trial 0 with value: 0.7384164492634121.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:20,075] Trial 1 finished with value: 0.7389736426689917 and parameters: {'n_estimators': 256, 'max_depth': 5, 'learning_rate': 0.04360361560272239, 'subsample': 0.8954321138062946, 'colsample_bytree': 0.7983599881821732, 'gamma': 3.6169975392746068}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:28,765] Trial 2 finished with value: 0.7380873031728143 and parameters: {'n_estimators': 477, 'max_depth': 12, 'learning_rate': 0.05403365484740024, 'subsample': 0.6385352024007555, 'colsample_bytree': 0.7148307480196004, 'gamma': 3.3949886327250836}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:36,629] Trial 3 finished with value: 0.7338160737587349 and parameters: {'n_estimators': 455, 'max_depth': 7, 'learning_rate': 0.2639798546157409, 'subsample': 0.6489381488284466, 'colsample_bytree': 0.7938357671599171, 'gamma': 2.8530872495621407}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:43,928] Trial 4 finished with value: 0.7246584750560119 and parameters: {'n_estimators': 369, 'max_depth': 11, 'learning_rate': 0.2645537421208913, 'subsample': 0.7418156991277364, 'colsample_bytree': 0.6071089662643184, 'gamma': 1.6640297642232489}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:46,940] Trial 5 finished with value: 0.7382504938191241 and parameters: {'n_estimators': 129, 'max_depth': 4, 'learning_rate': 0.0751569566106514, 'subsample': 0.8264735024175741, 'colsample_bytree': 0.6737721197013263, 'gamma': 2.398049282303254}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:52,424] Trial 6 finished with value: 0.7382943951445909 and parameters: {'n_estimators': 317, 'max_depth': 3, 'learning_rate': 0.24397992571588542, 'subsample': 0.7893222731931632, 'colsample_bytree': 0.8123575771761471, 'gamma': 1.7859811279722326}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:16:58,231] Trial 7 finished with value: 0.7384936726783723 and parameters: {'n_estimators': 322, 'max_depth': 4, 'learning_rate': 0.15523384394238038, 'subsample': 0.7297696239886988, 'colsample_bytree': 0.6044202439350381, 'gamma': 2.584479910992044}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:16:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:03,808] Trial 8 finished with value: 0.7375475018203363 and parameters: {'n_estimators': 346, 'max_depth': 10, 'learning_rate': 0.22350838894654684, 'subsample': 0.627643956626546, 'colsample_bytree': 0.6345530739059573, 'gamma': 4.884095286750706}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:09,484] Trial 9 finished with value: 0.7377886424647484 and parameters: {'n_estimators': 248, 'max_depth': 5, 'learning_rate': 0.02190268519131176, 'subsample': 0.8489767998663895, 'colsample_bytree': 0.8538285972688813, 'gamma': 0.0016643268858596016}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:13,365] Trial 10 finished with value: 0.7386019156095257 and parameters: {'n_estimators': 228, 'max_depth': 7, 'learning_rate': 0.11313926549008602, 'subsample': 0.983680303968356, 'colsample_bytree': 0.9758860452086676, 'gamma': 4.3503871735354105}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:17,344] Trial 11 finished with value: 0.7385641454096271 and parameters: {'n_estimators': 216, 'max_depth': 7, 'learning_rate': 0.11094983876710196, 'subsample': 0.9811558424959745, 'colsample_bytree': 0.9917667805397217, 'gamma': 4.425862547352579}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:21,170] Trial 12 finished with value: 0.7379727081904681 and parameters: {'n_estimators': 226, 'max_depth': 9, 'learning_rate': 0.12265493052454787, 'subsample': 0.9804540151409455, 'colsample_bytree': 0.9336052013657936, 'gamma': 3.8630792617984677}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:27,656] Trial 13 finished with value: 0.7365722973683724 and parameters: {'n_estimators': 257, 'max_depth': 6, 'learning_rate': 0.01045416664580049, 'subsample': 0.915024626239169, 'colsample_bytree': 0.8891734163087408, 'gamma': 3.966173354305468}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:31,313] Trial 14 finished with value: 0.7386290955549167 and parameters: {'n_estimators': 173, 'max_depth': 8, 'learning_rate': 0.08010301161312586, 'subsample': 0.9244615762116575, 'colsample_bytree': 0.7190195868655381, 'gamma': 4.987660966724398}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:35,379] Trial 15 finished with value: 0.7386093073437938 and parameters: {'n_estimators': 175, 'max_depth': 9, 'learning_rate': 0.06281039467754165, 'subsample': 0.9023159208932885, 'colsample_bytree': 0.7319319406088127, 'gamma': 3.441326412426542}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:37,894] Trial 16 finished with value: 0.738612660343845 and parameters: {'n_estimators': 120, 'max_depth': 8, 'learning_rate': 0.16517261214125736, 'subsample': 0.9073170122503873, 'colsample_bytree': 0.745067032918846, 'gamma': 4.897441682585071}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:43,882] Trial 17 finished with value: 0.7387518537158864 and parameters: {'n_estimators': 389, 'max_depth': 5, 'learning_rate': 0.08549170777649387, 'subsample': 0.9372591188588224, 'colsample_bytree': 0.6868145074256521, 'gamma': 3.3557579449925967}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:51,517] Trial 18 finished with value: 0.7389543121337055 and parameters: {'n_estimators': 402, 'max_depth': 5, 'learning_rate': 0.030538233988957376, 'subsample': 0.9489015405035689, 'colsample_bytree': 0.6759783093612495, 'gamma': 3.1360895180973465}. Best is trial 1 with value: 0.7389736426689917.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:17:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:17:59,917] Trial 19 finished with value: 0.739186392588026 and parameters: {'n_estimators': 425, 'max_depth': 5, 'learning_rate': 0.03210640911709611, 'subsample': 0.8700485191186913, 'colsample_bytree': 0.8487622591581592, 'gamma': 1.8293289192039388}. Best is trial 19 with value: 0.739186392588026.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:18:09,243] Trial 20 finished with value: 0.738649960279117 and parameters: {'n_estimators': 438, 'max_depth': 6, 'learning_rate': 0.042464044694623476, 'subsample': 0.7856899727128178, 'colsample_bytree': 0.864674726703967, 'gamma': 1.049350747753736}. Best is trial 19 with value: 0.739186392588026.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:18:17,316] Trial 21 finished with value: 0.7391528458515564 and parameters: {'n_estimators': 414, 'max_depth': 5, 'learning_rate': 0.03549791365108912, 'subsample': 0.8730972852153437, 'colsample_bytree': 0.8239030053942082, 'gamma': 1.9164820956559967}. Best is trial 19 with value: 0.739186392588026.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:18:23,452] Trial 22 finished with value: 0.7388275991655529 and parameters: {'n_estimators': 282, 'max_depth': 4, 'learning_rate': 0.04311717844005952, 'subsample': 0.877425136263094, 'colsample_bytree': 0.8298874445233572, 'gamma': 1.918008500401467}. Best is trial 19 with value: 0.739186392588026.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 20:18:34,939] Trial 23 finished with value: 0.7385760643741484 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.011768649421639993, 'subsample': 0.8300593167863279, 'colsample_bytree': 0.8984064892009843, 'gamma': 1.2097547798245896}. Best is trial 19 with value: 0.739186392588026.
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:18:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 505
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006032 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 504
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006591 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 503
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-16 20:21:28,964] Trial 27 finished with value: 0.7374770927229268 and parameters: {'n_estimators': 358, 'max_depth': 6, 'learning_rate': 0.01319719577742625, 'num_leaves': 22, 'subsample': 0.8945647079010014}. Best is trial 24 with value: 0.7387510938004842.
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 505
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 504
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006798 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006713 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007060 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 503
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-16 20:21:34,122] Trial 28 finished with value: 0.7360355245837298 and parameters: {'n_estimators': 438, 'max_depth': 8, 'learning_rate': 0.161482459917997, 'num_leaves': 17, 'subsample': 0.9510612283570673}. Best is trial 24 with value: 0.7387510938004842.
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006647 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 505
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006442 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 504
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006830 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006770 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 503
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-16 20:21:37,074] Trial 29 finished with value: 0.7387099890705857 and parameters: {'n_estimators': 119, 'max_depth': 9, 'learning_rate': 0.08316091661634574, 'num_leaves': 27, 'subsample': 0.8335663784249624}. Best is trial 24 with value: 0.7387510938004842.
# [I 2025-02-16 20:21:37,075] A new study created in memory with name: no-name-9f5f7859-b573-4062-9fe3-95f74d3cb79b
# Optimizing RandomForest...
# [I 2025-02-16 20:22:11,052] Trial 0 finished with value: 0.7184035562635367 and parameters: {'n_estimators': 141, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7184035562635367.
# [I 2025-02-16 20:23:17,819] Trial 1 finished with value: 0.7324764146637667 and parameters: {'n_estimators': 143, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.7324764146637667.
# [I 2025-02-16 20:24:10,174] Trial 2 finished with value: 0.7333873556970283 and parameters: {'n_estimators': 104, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.7333873556970283.
# [I 2025-02-16 20:25:54,164] Trial 3 finished with value: 0.7337183538498563 and parameters: {'n_estimators': 207, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.7337183538498563.
# [I 2025-02-16 20:27:01,692] Trial 4 finished with value: 0.7313890041381319 and parameters: {'n_estimators': 156, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.7337183538498563.
# [I 2025-02-16 20:29:31,681] Trial 5 finished with value: 0.733865517983099 and parameters: {'n_estimators': 298, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.733865517983099.
# [I 2025-02-16 20:29:59,895] Trial 6 finished with value: 0.7145668559586746 and parameters: {'n_estimators': 142, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.733865517983099.
# [I 2025-02-16 20:30:42,566] Trial 7 finished with value: 0.729585426625315 and parameters: {'n_estimators': 105, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 5 with value: 0.733865517983099.
# [I 2025-02-16 20:31:33,435] Trial 8 finished with value: 0.7224726181342168 and parameters: {'n_estimators': 181, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.733865517983099.
# [I 2025-02-16 20:31:59,119] Trial 9 finished with value: 0.7182702302151112 and parameters: {'n_estimators': 106, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 5 with value: 0.733865517983099.
# [I 2025-02-16 20:34:39,293] Trial 10 finished with value: 0.7345111641400106 and parameters: {'n_estimators': 298, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7345111641400106.
# [I 2025-02-16 20:37:20,246] Trial 11 finished with value: 0.7345169558196835 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.7345169558196835.
# [I 2025-02-16 20:39:58,752] Trial 12 finished with value: 0.7345131407590175 and parameters: {'n_estimators': 296, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.7345169558196835.
# [I 2025-02-16 20:41:32,952] Trial 13 finished with value: 0.7277867288652898 and parameters: {'n_estimators': 258, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.7345169558196835.
# [I 2025-02-16 20:43:47,619] Trial 14 finished with value: 0.7345224050671403 and parameters: {'n_estimators': 252, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 14 with value: 0.7345224050671403.
# [I 2025-02-16 20:45:17,887] Trial 15 finished with value: 0.7277653577722646 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 14 with value: 0.7345224050671403.
# [I 2025-02-16 20:47:11,222] Trial 16 finished with value: 0.7315024690085107 and parameters: {'n_estimators': 258, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 14 with value: 0.7345224050671403.
# [I 2025-02-16 20:49:14,870] Trial 17 finished with value: 0.734525478963404 and parameters: {'n_estimators': 231, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 17 with value: 0.734525478963404.
# [I 2025-02-16 20:50:59,213] Trial 18 finished with value: 0.7328411984952269 and parameters: {'n_estimators': 224, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 17 with value: 0.734525478963404.
# [I 2025-02-16 20:52:12,998] Trial 19 finished with value: 0.7253380951927453 and parameters: {'n_estimators': 232, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 17 with value: 0.734525478963404.
# [I 2025-02-16 20:54:19,803] Trial 20 finished with value: 0.7328222101800111 and parameters: {'n_estimators': 273, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 17 with value: 0.734525478963404.
# [I 2025-02-16 20:56:45,311] Trial 21 finished with value: 0.7345275137636623 and parameters: {'n_estimators': 276, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 20:58:50,667] Trial 22 finished with value: 0.7344460387484696 and parameters: {'n_estimators': 236, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:01:04,870] Trial 23 finished with value: 0.7337516820030269 and parameters: {'n_estimators': 270, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:02:35,858] Trial 24 finished with value: 0.7313890912702655 and parameters: {'n_estimators': 210, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:05:02,646] Trial 25 finished with value: 0.7344900257289748 and parameters: {'n_estimators': 276, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:06:55,822] Trial 26 finished with value: 0.7327767935233841 and parameters: {'n_estimators': 244, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:08:31,976] Trial 27 finished with value: 0.7336677888919124 and parameters: {'n_estimators': 193, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:10:00,487] Trial 28 finished with value: 0.7297493306829554 and parameters: {'n_estimators': 222, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7345275137636623.
# [I 2025-02-16 21:12:30,376] Trial 29 finished with value: 0.7343451216623054 and parameters: {'n_estimators': 282, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 21 with value: 0.7345275137636623.

# %%
# 최적화된 모델 생성
xgb_model = XGBClassifier(**best_xgb_params, random_state=42, use_label_encoder=False, eval_metric="logloss")
lgbm_model = LGBMClassifier(**best_lgbm_params, random_state=42)
rf_model = RandomForestClassifier(**best_rf_params, random_state=42)

# %%
# XGBoost 모델의 파라미터 확인
print("XGBoost Best Parameters:")
print(xgb_model.get_params())

# LightGBM 모델의 파라미터 확인
print("\nLightGBM Best Parameters:")
print(lgbm_model.get_params())

# RandomForest 모델의 파라미터 확인
print("\nRandomForest Best Parameters:")
print(rf_model.get_params())
# Out:
# XGBoost Best Parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8487622591581592, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': 'logloss', 'feature_types': None, 'gamma': 1.8293289192039388, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.03210640911709611, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 5, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 425, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8700485191186913, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'use_label_encoder': False}
#
# LightGBM Best Parameters:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.05711281803665102, 'max_depth': 6, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 334, 'n_jobs': None, 'num_leaves': 23, 'objective': None, 'random_state': 42, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8337439510172372, 'subsample_for_bin': 200000, 'subsample_freq': 0}
#
# RandomForest Best Parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 12, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 3, 'min_samples_split': 5, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 276, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
# Soft Voting 앙상블
ensemble_model = VotingClassifier(
    estimators=[
        ("xgb", xgb_model),
        ("lgbm", lgbm_model),
        ("rf", rf_model)
    ],
    voting="soft"
)

# %%
# 전체 데이터로 학습
ensemble_model.fit(X_train_encoded, y)
# Out:
# c:\Users\hoyeong\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:12:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 505
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# VotingClassifier(estimators=[('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8487622591581592,
#                                             device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None,
#                                             gamma=1.8293289192039388,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interac...
#                                             n_estimators=425, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=42, ...)),
#                              ('lgbm',
#                               LGBMClassifier(learning_rate=0.05711281803665102,
#                                              max_depth=6, n_estimators=334,
#                                              num_leaves=23, random_state=42,
#                                              subsample=0.8337439510172372)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=12,
#                                                      min_samples_leaf=3,
#                                                      min_samples_split=5,
#                                                      n_estimators=276,
#                                                      random_state=42))],
#                  voting='soft')

# %% [markdown]
# ### Predict

# %%
pred_proba = ensemble_model.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('../../sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./Result/baseline_submit.csv', index=False)

# %%
pred_proba
# Out:
# array([0.00341224, 0.00397266, 0.15047629, ..., 0.43625377, 0.25047644,
#        0.00290478])

# %%
unique, counts = np.unique(sample_submission['probability'], return_counts=True)
print(unique, counts)
# Out:
# [1.79142742e-04 1.80215013e-04 2.08479061e-04 ... 6.88630623e-01
#  6.90734825e-01 7.05926664e-01] [1 1 1 ... 1 1 1]
