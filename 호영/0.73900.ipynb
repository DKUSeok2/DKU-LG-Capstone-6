# %% [markdown]
# ### Import

# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import seaborn as sns

# 각 라이브러리 버전 출력
print("Numpy version:", np.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# Numpy version: 1.26.4
# Scikit-learn version: 1.5.1
# Pandas version: 1.5.3
# Matplotlib version: 3.9.2
# Seaborn version: 0.13.2

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import  OrdinalEncoder
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# ### Data Load

# %%
import sys
import os
import pandas as pd

# 현재 작업 디렉토리 경로를 가져와 shared codes 폴더의 위치를 sys.path에 추가합니다.
# sys.path에 추가된 경로에 있는 py 폴더는 임포트할 수 있다.
current_dir = os.getcwd()
shared_codes_dir = os.path.join(current_dir, '../shared codes')
sys.path.append(shared_codes_dir)


# cover_nan 모듈을 임포트
from cover_nan import missing_value_removal_function

# 원본 train 데이터 로드
train = pd.read_csv("../shared codes/data/train.csv")
test = pd.read_csv("../shared codes/data/test.csv")

# missing_value_removal_function 사용
train = missing_value_removal_function(train)
test = missing_value_removal_function(test)
# Out:
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부']
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부']

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# 난자 채취 경과일     57488
# 난자 해동 경과일    254915
# 난자 혼합 경과일     53735
# 배아 이식 경과일     43566
# 배아 해동 경과일    215982
# dtype: int64

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('알 수 없음').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ '알 수 없음' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 5
#       2 unknown_columns = []
#       4 for col in X.columns:
# ----> 5     if X[col].astype(str).str.contains('알 수 없음').any():
#       6         unknown_columns.append(col)
#       8 # 결과 출력
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\core\strings\accessor.py:1260, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1252 if regex and re.compile(pat).groups:
#    1253     warnings.warn(
#    1254         "This pattern is interpreted as a regular expression, and has "
#    1255         "match groups. To actually get the groups, use str.extract.",
#    1256         UserWarning,
#    1257         stacklevel=find_stack_level(),
#    1258     )
# -> 1260 result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1261 return self._wrap_result(result, fill_value=na, returns_string=False)
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\core\strings\object_array.py:131, in ObjectStringArrayMixin._str_contains(self, pat, case, flags, na, regex)
#     129         upper_pat = pat.upper()
#     130         f = lambda x: upper_pat in x.upper()
# --> 131 return self._str_map(f, na, dtype=np.dtype("bool"))
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\core\strings\object_array.py:71, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      69 map_convert = convert and not np.all(mask)
#      70 try:
# ---> 71     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      72 except (TypeError, AttributeError) as err:
#      73     # Reraise the exception if callable `f` got wrong number of args.
#      74     # The user may want to be warned by this, instead of getting NaN
#      75     p_err = (
#      76         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      77         r"(?(3)required )positional arguments?"
#      78     )
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\_libs\lib.pyx:2876, in pandas._libs.lib.map_infer_mask()
#
# File c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\pandas\core\strings\object_array.py:124, in ObjectStringArrayMixin._str_contains.<locals>.<lambda>(x)
#     120         flags |= re.IGNORECASE
#     122     pat = re.compile(pat, flags=flags)
# --> 124     f = lambda x: pat.search(x) is not None
#     125 else:
#     126     if case:
#
# KeyboardInterrupt:

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('nan').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ 'nan' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ⚠️ 'nan' 값을 포함하는 컬럼들:
# ['난자 채취 경과일', '난자 해동 경과일', '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일']

# %%
# NaN 값이 존재하는 컬럼 찾기
unknown_columns = X.columns[X.isna().any()].tolist()

unknown_columns
# Out:
# ['난자 채취 경과일', '난자 해동 경과일', '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일']

# %%
# Categorical(범주형) 칼럼 찾기
categorical_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()

# 결과 출력
print("📌 Categorical(범주형) 칼럼 리스트:")
print(categorical_columns)
# Out:
# 📌 Categorical(범주형) 칼럼 리스트:
# ['ID', '시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', '총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수', 'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '난자 출처', '정자 출처', '난자 기증자 나이', '정자 기증자 나이']

# %%
X['난자 채취 경과일'].fillna(1, inplace=True)
X['난자 해동 경과일'].fillna(0, inplace=True)
X['난자 혼합 경과일'].fillna(0, inplace=True)
X['배아 이식 경과일'].fillna(0, inplace=True)
X['배아 해동 경과일'].fillna(0, inplace=True)

test['난자 채취 경과일'].fillna(1, inplace=True)
test['난자 해동 경과일'].fillna(0, inplace=True)
test['난자 혼합 경과일'].fillna(0, inplace=True)
test['배아 이식 경과일'].fillna(0, inplace=True)
test['배아 해동 경과일'].fillna(0, inplace=True)

# %%
# 병합할 칼럼들
columns_to_merge = [
    '난자 채취 경과일', '난자 해동 경과일', '난자 혼합 경과일',
    '배아 이식 경과일', '배아 해동 경과일'
]

# 새로운 칼럼 생성: 각 경과일의 합
X['총 경과일'] = X[columns_to_merge].sum(axis=1)

# 기존 칼럼 제거
X = X.drop(columns=columns_to_merge)

# 새로운 칼럼 생성: 각 경과일의 합
test['총 경과일'] = test[columns_to_merge].sum(axis=1)

# 기존 칼럼 제거
test = test.drop(columns=columns_to_merge)

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
columns_to_drop = [
        "남성 주 불임 원인",
        "남성 부 불임 원인",
        "불임 원인 - 정자 농도",
        "불임 원인 - 정자 면역학적 요인",
        "불임 원인 - 정자 운동성",
        "불임 원인 - 정자 형태",
        '정자 기증자 나이',
        '배란 유도 유형'
]
X_train_encoded = X_train_encoded.drop(columns = columns_to_drop)    
X_test_encoded = X_test_encoded.drop(columns = columns_to_drop)

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X_train_encoded.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# Series([], dtype: int64)

# %%
X_train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256351 entries, 0 to 256350
# Data columns (total 51 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                256351 non-null  float64
#  1   시술 시기 코드          256351 non-null  float64
#  2   시술 당시 나이          256351 non-null  float64
#  3   시술 유형             256351 non-null  float64
#  4   특정 시술 유형          256351 non-null  float64
#  5   배란 자극 여부          256351 non-null  int64
#  6   단일 배아 이식 여부       256351 non-null  float64
#  7   여성 주 불임 원인        256351 non-null  int64
#  8   여성 부 불임 원인        256351 non-null  int64
#  9   부부 주 불임 원인        256351 non-null  int64
#  10  부부 부 불임 원인        256351 non-null  int64
#  11  불명확 불임 원인         256351 non-null  int64
#  12  불임 원인 - 난관 질환     256351 non-null  int64
#  13  불임 원인 - 남성 요인     256351 non-null  int64
#  14  불임 원인 - 배란 장애     256351 non-null  int64
#  15  불임 원인 - 여성 요인     256351 non-null  int64
#  16  불임 원인 - 자궁경부 문제   256351 non-null  int64
#  17  불임 원인 - 자궁내막증     256351 non-null  int64
#  18  배아 생성 주요 이유       256351 non-null  int64
#  19  총 시술 횟수           256351 non-null  float64
#  20  클리닉 내 총 시술 횟수     256351 non-null  float64
#  21  IVF 시술 횟수         256351 non-null  float64
#  22  DI 시술 횟수          256351 non-null  float64
#  23  총 임신 횟수           256351 non-null  float64
#  24  IVF 임신 횟수         256351 non-null  float64
#  25  DI 임신 횟수          256351 non-null  float64
#  26  총 출산 횟수           256351 non-null  float64
#  27  IVF 출산 횟수         256351 non-null  float64
#  28  DI 출산 횟수          256351 non-null  float64
#  29  총 생성 배아 수         256351 non-null  float64
#  30  미세주입된 난자 수        256351 non-null  float64
#  31  미세주입에서 생성된 배아 수   256351 non-null  float64
#  32  이식된 배아 수          256351 non-null  float64
#  33  미세주입 배아 이식 수      256351 non-null  float64
#  34  저장된 배아 수          256351 non-null  float64
#  35  미세주입 후 저장된 배아 수   256351 non-null  float64
#  36  해동된 배아 수          256351 non-null  float64
#  37  해동 난자 수           256351 non-null  float64
#  38  수집된 신선 난자 수       256351 non-null  float64
#  39  저장된 신선 난자 수       256351 non-null  float64
#  40  혼합된 난자 수          256351 non-null  float64
#  41  파트너 정자와 혼합된 난자 수  256351 non-null  float64
#  42  기증자 정자와 혼합된 난자 수  256351 non-null  float64
#  43  난자 출처             256351 non-null  float64
#  44  정자 출처             256351 non-null  float64
#  45  난자 기증자 나이         256351 non-null  float64
#  46  동결 배아 사용 여부       256351 non-null  float64
#  47  신선 배아 사용 여부       256351 non-null  float64
#  48  기증 배아 사용 여부       256351 non-null  float64
#  49  대리모 여부            256351 non-null  float64
#  50  총 경과일             256351 non-null  float64
# dtypes: float64(38), int64(13)
# memory usage: 99.7 MB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 데이터 정규화 (X_train_encoded & X_test_encoded)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)  # 동일한 스케일 적용

# DataFrame 변환 (Feature 이름 유지)
feature_names = [f"Feature_{i}" for i in range(X_train_scaled.shape[1])]
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=feature_names)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=feature_names)

# 상관 행렬 계산
correlation_matrix_train = X_train_scaled_df.corr()

# 다중 공선성이 높은 칼럼 찾기 (절대 상관 계수가 0.8 이상)
threshold = 0.8
high_corr_features = set()

for i in range(len(feature_names)):
    for j in range(i + 1, len(feature_names)):
        if abs(correlation_matrix_train.iloc[i, j]) > threshold:
            high_corr_features.add(feature_names[j])  # 공선성이 높은 컬럼 추가

# 다중 공선성이 높은 컬럼 제거
X_train_encoded = X_train_scaled_df.drop(columns=high_corr_features, errors='ignore')
X_test_encoded = X_test_scaled_df.drop(columns=high_corr_features, errors='ignore')

# %%
X_train_encoded
# Out:
#         Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0       -1.732044   1.518507  -0.935575   0.158613  -0.962962   0.544551
# 1       -1.732031   1.020975   2.655919   0.158613  -0.962962  -1.836376
# 2       -1.732017   0.025910  -0.935575   0.158613   0.672585   0.544551
# 3       -1.732004  -0.471622  -0.217277   0.158613  -0.962962   0.544551
# 4       -1.731990   0.025910  -0.935575   0.158613  -0.962962   0.544551
# ...           ...        ...        ...        ...        ...        ...
# 256346   1.731990   1.020975  -0.935575   0.158613  -0.962962   0.544551
# 256347   1.732004   1.020975   0.501022   0.158613  -0.962962   0.544551
# 256348   1.732017   0.025910  -0.217277   0.158613  -0.962962   0.544551
# 256349   1.732031   1.518507   0.501022   0.158613  -0.962962   0.544551
# 256350   1.732044   0.523442  -0.217277   0.158613   0.672585  -1.836376
#
#         Feature_6  Feature_7  Feature_8  Feature_10  ...  Feature_37  \
# 0       -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 1       -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 2       -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 3       -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 4       -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# ...           ...        ...        ...         ...  ...         ...
# 256346  -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 256347  -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 256348  -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 256349  -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
# 256350  -0.543057  -0.178038  -0.112199   -0.094036  ...   -0.066583
#
#         Feature_38  Feature_39  Feature_42  Feature_43  Feature_44  \
# 0        -0.184224   -0.083423   -0.220261    0.256018    0.344047
# 1        -1.000848   -0.083423   -0.220261    0.256018    0.344047
# 2        -0.048121   -0.083423   -0.220261    0.256018    0.344047
# 3        -0.456432   -0.083423   -0.220261    0.256018    0.344047
# 4        -0.184224   -0.083423   -0.220261    0.256018    0.344047
# ...            ...         ...         ...         ...         ...
# 256346    0.360191   -0.083423   -0.220261    0.256018    0.344047
# 256347   -0.456432   -0.083423   -0.220261    0.256018    0.344047
# 256348    0.224087   -0.083423   -0.220261    0.256018    0.344047
# 256349   -0.728640   -0.083423   -0.220261    0.256018    0.344047
# 256350   -1.136951   -0.083423   -0.220261    0.256018    0.344047
#
#         Feature_46  Feature_48  Feature_49  Feature_50
# 0        -0.430784   -0.098393     -0.0641    0.033850
# 1        -0.430784   -0.098393     -0.0641   -1.586105
# 2        -0.430784   -0.098393     -0.0641   -0.506135
# 3        -0.430784   -0.098393     -0.0641   -1.586105
# 4        -0.430784   -0.098393     -0.0641    0.033850
# ...            ...         ...         ...         ...
# 256346   -0.430784   -0.098393     -0.0641    1.113821
# 256347   -0.430784   -0.098393     -0.0641    0.033850
# 256348   -0.430784   -0.098393     -0.0641    0.033850
# 256349   -0.430784   -0.098393     -0.0641   -1.046120
# 256350    2.321347   -0.098393     -0.0641   -1.046120
#
# [256351 rows x 40 columns]

# %% [markdown]
# ### Train

# %%
model = ExtraTreesClassifier(random_state=42)

model.fit(X_train_encoded, y)
# Out:
# ExtraTreesClassifier(random_state=42)

# %% [markdown]
# **앙상블 및 Optuna**

# %%
import optuna
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np

# %%
def optimize_xgboost(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5)
    }
    model = XGBClassifier(**params, random_state=42, use_label_encoder=False, eval_metric="logloss")
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")
    return np.mean(scores)

# %%
def optimize_lightgbm(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 10, 50),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0)
    }
    model = LGBMClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
def optimize_random_forest(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 200),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_samples_split": trial.suggest_int("min_samples_split", 3, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 4)
    }
    model = RandomForestClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
# Optuna 스터디 실행
print("Optimizing XGBoost...")
xgb_study = optuna.create_study(direction="maximize")
xgb_study.optimize(optimize_xgboost, n_trials=30)
best_xgb_params = xgb_study.best_params

print("Optimizing LightGBM...")
lgbm_study = optuna.create_study(direction="maximize")
lgbm_study.optimize(optimize_lightgbm, n_trials=30)
best_lgbm_params = lgbm_study.best_params

print("Optimizing RandomForest...")
rf_study = optuna.create_study(direction="maximize")
rf_study.optimize(optimize_random_forest, n_trials=30)
best_rf_params = rf_study.best_params
# Out:
# [I 2025-02-13 22:56:30,988] A new study created in memory with name: no-name-a47933c0-f714-4c8a-b9ee-ba85dffae9c6
# Optimizing XGBoost...
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:31] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:32] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:33] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:34] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:35] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:56:36,127] Trial 0 finished with value: 0.7201280233673217 and parameters: {'n_estimators': 182, 'max_depth': 11, 'learning_rate': 0.25113942464425404, 'subsample': 0.9764245094791814, 'colsample_bytree': 0.8499457035920966, 'gamma': 1.2956016771416419}. Best is trial 0 with value: 0.7201280233673217.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:36] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:37] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:38] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:39] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:40] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:56:41,823] Trial 1 finished with value: 0.735677876196681 and parameters: {'n_estimators': 196, 'max_depth': 5, 'learning_rate': 0.09476647677888306, 'subsample': 0.8900078377444091, 'colsample_bytree': 0.8560373761207596, 'gamma': 2.552680281446331}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:41] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:42] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:43] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:44] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:56:45,654] Trial 2 finished with value: 0.7332866199301139 and parameters: {'n_estimators': 131, 'max_depth': 5, 'learning_rate': 0.2879783329986378, 'subsample': 0.7722373660496233, 'colsample_bytree': 0.8491467150329222, 'gamma': 4.238771541397756}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:47] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:48] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:50] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:52] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:56:53,780] Trial 3 finished with value: 0.7315975896876333 and parameters: {'n_estimators': 384, 'max_depth': 10, 'learning_rate': 0.16780636600688936, 'subsample': 0.6099725317323664, 'colsample_bytree': 0.6291887707565079, 'gamma': 4.599805613430238}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:53] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:55] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:57] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:58] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:56:59] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:01,390] Trial 4 finished with value: 0.7355780944489909 and parameters: {'n_estimators': 346, 'max_depth': 3, 'learning_rate': 0.1563173625133925, 'subsample': 0.9891482577600051, 'colsample_bytree': 0.7331247940430681, 'gamma': 1.0693723925121739}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:01] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:04] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:07] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:09] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:12] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:15,346] Trial 5 finished with value: 0.7295053856265026 and parameters: {'n_estimators': 420, 'max_depth': 12, 'learning_rate': 0.03246089553271104, 'subsample': 0.7781438928128381, 'colsample_bytree': 0.9707516723529853, 'gamma': 2.464216552370739}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:15] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:17] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:20] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:22] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:24] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:26,939] Trial 6 finished with value: 0.7093611139984822 and parameters: {'n_estimators': 349, 'max_depth': 8, 'learning_rate': 0.14579456565726628, 'subsample': 0.907285705880658, 'colsample_bytree': 0.8485023409201417, 'gamma': 0.3282767951385074}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:27] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:28] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:30] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:31] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:33] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:34,966] Trial 7 finished with value: 0.7324272588744574 and parameters: {'n_estimators': 286, 'max_depth': 6, 'learning_rate': 0.07125580712369346, 'subsample': 0.6275048702956816, 'colsample_bytree': 0.621812388612989, 'gamma': 1.5463045603001502}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:35] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:37] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:39] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:41] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:43] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:45,098] Trial 8 finished with value: 0.7353904282641001 and parameters: {'n_estimators': 440, 'max_depth': 5, 'learning_rate': 0.08439579905350272, 'subsample': 0.8373280708391908, 'colsample_bytree': 0.782978896697119, 'gamma': 2.9456802979700276}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:46] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:48] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:50] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:52] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:57:54,735] Trial 9 finished with value: 0.7271336163103668 and parameters: {'n_estimators': 414, 'max_depth': 6, 'learning_rate': 0.1639700154160099, 'subsample': 0.7391538613920695, 'colsample_bytree': 0.7821079663748006, 'gamma': 2.285170001382921}. Best is trial 1 with value: 0.735677876196681.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:54] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:55] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:56] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:58] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:57:59] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:00,523] Trial 10 finished with value: 0.7373808941215462 and parameters: {'n_estimators': 236, 'max_depth': 3, 'learning_rate': 0.10255883664151794, 'subsample': 0.8971782431870612, 'colsample_bytree': 0.9871407719666874, 'gamma': 3.469435093999322}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:00] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:01] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:02] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:03] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:04] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:05,848] Trial 11 finished with value: 0.737376051849987 and parameters: {'n_estimators': 227, 'max_depth': 3, 'learning_rate': 0.098760142719418, 'subsample': 0.8708028817864218, 'colsample_bytree': 0.9992783858050617, 'gamma': 3.6498386224527852}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:05] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:07] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:08] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:09] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:11] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:12,329] Trial 12 finished with value: 0.7350249853119021 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.02584369412813385, 'subsample': 0.8800394098185211, 'colsample_bytree': 0.9911149095111156, 'gamma': 3.688604289390292}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:12] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:13] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:14] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:15] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:16] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:17,646] Trial 13 finished with value: 0.7371723248483161 and parameters: {'n_estimators': 216, 'max_depth': 3, 'learning_rate': 0.11063953892724795, 'subsample': 0.9182750019452159, 'colsample_bytree': 0.9406733731847303, 'gamma': 3.5352086691520834}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:17] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:19] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:21] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:23] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:25] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:27,609] Trial 14 finished with value: 0.7358140825117254 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.12314844290005818, 'subsample': 0.8322494216141049, 'colsample_bytree': 0.9187695611400617, 'gamma': 4.901532798044807}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:27] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:28] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:29] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:29] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:30] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:31,215] Trial 15 finished with value: 0.7359796372215734 and parameters: {'n_estimators': 116, 'max_depth': 4, 'learning_rate': 0.20162552682622928, 'subsample': 0.7001743088076691, 'colsample_bytree': 0.9113498267935917, 'gamma': 3.618156322314387}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:31] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:32] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:34] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:35] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:37] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:38,445] Trial 16 finished with value: 0.7343079242586082 and parameters: {'n_estimators': 250, 'max_depth': 7, 'learning_rate': 0.047290108740125306, 'subsample': 0.9468781285587614, 'colsample_bytree': 0.9995971518539394, 'gamma': 3.1139380659881333}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:38] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:39] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:39] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:40] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:41] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:41,859] Trial 17 finished with value: 0.7367821630682776 and parameters: {'n_estimators': 160, 'max_depth': 4, 'learning_rate': 0.20085589954884375, 'subsample': 0.8439724593450313, 'colsample_bytree': 0.7156886045762594, 'gamma': 4.059863001431721}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:42] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:43] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:44] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:47] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:48,222] Trial 18 finished with value: 0.7372189251317859 and parameters: {'n_estimators': 293, 'max_depth': 4, 'learning_rate': 0.05524565453668649, 'subsample': 0.8615554231607452, 'colsample_bytree': 0.9415665783631825, 'gamma': 3.109144330466687}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:48] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:49] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:50] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:51] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:52] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:53,147] Trial 19 finished with value: 0.7300935830071866 and parameters: {'n_estimators': 229, 'max_depth': 9, 'learning_rate': 0.1086017430317666, 'subsample': 0.950388799606579, 'colsample_bytree': 0.8856000298312297, 'gamma': 1.9967785685179191}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:53] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:54] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:56] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:57] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:58:58] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:58:59,888] Trial 20 finished with value: 0.7345374864218412 and parameters: {'n_estimators': 319, 'max_depth': 6, 'learning_rate': 0.1992615742236433, 'subsample': 0.806100983617682, 'colsample_bytree': 0.9617650421224947, 'gamma': 4.191275782024266}. Best is trial 10 with value: 0.7373808941215462.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:00] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:01] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:02] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:04] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:05] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:06,913] Trial 21 finished with value: 0.7374899975098375 and parameters: {'n_estimators': 288, 'max_depth': 4, 'learning_rate': 0.05447202653154498, 'subsample': 0.8623212840764308, 'colsample_bytree': 0.9453438326895908, 'gamma': 3.0801460548842856}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:07] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:08] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:09] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:10] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:11] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:13,129] Trial 22 finished with value: 0.7298060759958906 and parameters: {'n_estimators': 272, 'max_depth': 3, 'learning_rate': 0.011724701886489164, 'subsample': 0.9189533821056777, 'colsample_bytree': 0.9984796595091511, 'gamma': 2.905679715009189}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:13] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:14] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:15] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:16] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:17] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:18,499] Trial 23 finished with value: 0.7372367614568036 and parameters: {'n_estimators': 230, 'max_depth': 4, 'learning_rate': 0.06642503489266484, 'subsample': 0.8025248020908619, 'colsample_bytree': 0.9042803339293053, 'gamma': 3.395357555750233}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:18] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:19] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:20] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:20] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:21] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:22,182] Trial 24 finished with value: 0.7373396302832681 and parameters: {'n_estimators': 165, 'max_depth': 3, 'learning_rate': 0.12993141074880643, 'subsample': 0.8727535500027003, 'colsample_bytree': 0.9582950610915031, 'gamma': 4.143022241762472}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:22] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:23] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:24] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:26] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:27] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:29,130] Trial 25 finished with value: 0.73637184807654 and parameters: {'n_estimators': 322, 'max_depth': 5, 'learning_rate': 0.09075362702226324, 'subsample': 0.946206939614032, 'colsample_bytree': 0.8844420333076587, 'gamma': 3.8695853586281177}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:29] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:30] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:31] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:33] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:34] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:35,400] Trial 26 finished with value: 0.7367752922082513 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.05014569976895396, 'subsample': 0.7170380806707701, 'colsample_bytree': 0.9359528200202484, 'gamma': 1.9293622720294055}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:35] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:37] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:38] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:39] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:41] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:42,688] Trial 27 finished with value: 0.733161250365726 and parameters: {'n_estimators': 239, 'max_depth': 7, 'learning_rate': 0.07765257360538194, 'subsample': 0.816203714542106, 'colsample_bytree': 0.9724906521112476, 'gamma': 2.7168194946436444}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:42] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:44] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:46] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:47] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-13 22:59:49,012] Trial 28 finished with value: 0.7367765282282144 and parameters: {'n_estimators': 311, 'max_depth': 3, 'learning_rate': 0.13586033087715965, 'subsample': 0.8567721242471956, 'colsample_bytree': 0.6662185406879442, 'gamma': 3.31059933018234}. Best is trial 21 with value: 0.7374899975098375.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:49] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:49] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:50] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:51] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [22:59:52] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 754
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007371 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 753
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006778 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 750
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006806 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 755
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 752
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-13 23:01:58,470] Trial 27 finished with value: 0.7354888534376861 and parameters: {'n_estimators': 349, 'max_depth': 9, 'learning_rate': 0.010534605878431115, 'num_leaves': 17, 'subsample': 0.7648497767486402}. Best is trial 23 with value: 0.737675240147702.
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006856 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 754
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007722 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 753
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007011 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 750
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005949 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 755
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 752
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-13 23:02:02,090] Trial 28 finished with value: 0.7281191333243657 and parameters: {'n_estimators': 239, 'max_depth': 11, 'learning_rate': 0.28968033974325447, 'num_leaves': 14, 'subsample': 0.6747410569545219}. Best is trial 23 with value: 0.737675240147702.
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 754
# [LightGBM] [Info] Number of data points in the train set: 205080, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 753
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52983, number of negative: 152098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 750
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054554
# [LightGBM] [Info] Start training from score -1.054554
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006922 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 755
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [LightGBM] [Info] Number of positive: 52982, number of negative: 152099
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006718 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 752
# [LightGBM] [Info] Number of data points in the train set: 205081, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258347 -> initscore=-1.054579
# [LightGBM] [Info] Start training from score -1.054579
# [I 2025-02-13 23:02:06,802] Trial 29 finished with value: 0.7357626240525259 and parameters: {'n_estimators': 284, 'max_depth': 10, 'learning_rate': 0.05988639396471875, 'num_leaves': 18, 'subsample': 0.6947473452828958}. Best is trial 23 with value: 0.737675240147702.
# [I 2025-02-13 23:02:06,803] A new study created in memory with name: no-name-ae7c2998-d6b5-434d-947f-88c7edd776d3
# Optimizing RandomForest...
# [I 2025-02-13 23:02:19,896] Trial 0 finished with value: 0.7149170914183395 and parameters: {'n_estimators': 56, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.7149170914183395.
# [I 2025-02-13 23:02:55,810] Trial 1 finished with value: 0.7163735318786362 and parameters: {'n_estimators': 162, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.7163735318786362.
# [I 2025-02-13 23:03:24,670] Trial 2 finished with value: 0.7292889547208781 and parameters: {'n_estimators': 61, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.7292889547208781.
# [I 2025-02-13 23:04:04,991] Trial 3 finished with value: 0.7274887189235196 and parameters: {'n_estimators': 94, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.7292889547208781.
# [I 2025-02-13 23:05:00,011] Trial 4 finished with value: 0.7310602665658145 and parameters: {'n_estimators': 92, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 4 with value: 0.7310602665658145.
# [I 2025-02-13 23:05:24,527] Trial 5 finished with value: 0.7189706280451836 and parameters: {'n_estimators': 88, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 4 with value: 0.7310602665658145.
# [I 2025-02-13 23:06:20,164] Trial 6 finished with value: 0.7230307705727175 and parameters: {'n_estimators': 167, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 4 with value: 0.7310602665658145.
# [I 2025-02-13 23:07:03,269] Trial 7 finished with value: 0.7323088075318703 and parameters: {'n_estimators': 66, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.7323088075318703.
# [I 2025-02-13 23:07:49,707] Trial 8 finished with value: 0.7302541354593837 and parameters: {'n_estimators': 88, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.7323088075318703.
# [I 2025-02-13 23:09:24,466] Trial 9 finished with value: 0.7297861894227904 and parameters: {'n_estimators': 199, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 7 with value: 0.7323088075318703.
# [I 2025-02-13 23:10:45,817] Trial 10 finished with value: 0.7328397996426959 and parameters: {'n_estimators': 125, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:12:08,580] Trial 11 finished with value: 0.7328101643344616 and parameters: {'n_estimators': 128, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:13:24,829] Trial 12 finished with value: 0.732435380635071 and parameters: {'n_estimators': 129, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:14:40,092] Trial 13 finished with value: 0.7316448381117727 and parameters: {'n_estimators': 135, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:16:13,975] Trial 14 finished with value: 0.732470341459151 and parameters: {'n_estimators': 149, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:17:18,497] Trial 15 finished with value: 0.7319261985597497 and parameters: {'n_estimators': 117, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:17:58,644] Trial 16 finished with value: 0.7260066229201378 and parameters: {'n_estimators': 108, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:19:29,872] Trial 17 finished with value: 0.7325240519840828 and parameters: {'n_estimators': 145, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:21:10,291] Trial 18 finished with value: 0.731533157977784 and parameters: {'n_estimators': 183, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:22:16,274] Trial 19 finished with value: 0.7323090433238619 and parameters: {'n_estimators': 113, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:23:28,146] Trial 20 finished with value: 0.7306572175255581 and parameters: {'n_estimators': 142, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:25:05,717] Trial 21 finished with value: 0.7325396303397933 and parameters: {'n_estimators': 155, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:26:45,190] Trial 22 finished with value: 0.7327823492811463 and parameters: {'n_estimators': 156, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:28:25,452] Trial 23 finished with value: 0.7323066712541324 and parameters: {'n_estimators': 171, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:29:46,095] Trial 24 finished with value: 0.7322244869187553 and parameters: {'n_estimators': 129, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:30:40,039] Trial 25 finished with value: 0.7307581676261856 and parameters: {'n_estimators': 104, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:31:46,436] Trial 26 finished with value: 0.7318686472785267 and parameters: {'n_estimators': 120, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:33:34,635] Trial 27 finished with value: 0.7316234222783855 and parameters: {'n_estimators': 182, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:34:59,924] Trial 28 finished with value: 0.732313043646343 and parameters: {'n_estimators': 134, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.7328397996426959.
# [I 2025-02-13 23:36:31,940] Trial 29 finished with value: 0.7324264196340314 and parameters: {'n_estimators': 156, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7328397996426959.

# %%
# 최적화된 모델 생성
xgb_model = XGBClassifier(**best_xgb_params, random_state=42, use_label_encoder=False, eval_metric="logloss")
lgbm_model = LGBMClassifier(**best_lgbm_params, random_state=42)
rf_model = RandomForestClassifier(**best_rf_params, random_state=42)

# %%
# XGBoost 모델의 파라미터 확인
print("XGBoost Best Parameters:")
print(xgb_model.get_params())

# LightGBM 모델의 파라미터 확인
print("\nLightGBM Best Parameters:")
print(lgbm_model.get_params())

# RandomForest 모델의 파라미터 확인
print("\nRandomForest Best Parameters:")
print(rf_model.get_params())
# Out:
# XGBoost Best Parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9453438326895908, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': 'logloss', 'feature_types': None, 'gamma': 3.0801460548842856, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.05447202653154498, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 288, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8623212840764308, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'use_label_encoder': False}
#
# LightGBM Best Parameters:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.04665361632686677, 'max_depth': 8, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 250, 'n_jobs': None, 'num_leaves': 10, 'objective': None, 'random_state': 42, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.7357412703290791, 'subsample_for_bin': 200000, 'subsample_freq': 0}
#
# RandomForest Best Parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 12, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 125, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
# Soft Voting 앙상블
ensemble_model = VotingClassifier(
    estimators=[
        ("xgb", xgb_model),
        ("lgbm", lgbm_model),
        ("rf", rf_model)
    ],
    voting="soft"
)

# %%
# 전체 데이터로 학습
ensemble_model.fit(X_train_encoded, y)
# Out:
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [23:36:32] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008248 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 754
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# VotingClassifier(estimators=[('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.9453438326895908,
#                                             device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None,
#                                             gamma=3.0801460548842856,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interac...
#                                             n_estimators=288, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=42, ...)),
#                              ('lgbm',
#                               LGBMClassifier(learning_rate=0.04665361632686677,
#                                              max_depth=8, n_estimators=250,
#                                              num_leaves=10, random_state=42,
#                                              subsample=0.7357412703290791)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=12,
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=3,
#                                                      n_estimators=125,
#                                                      random_state=42))],
#                  voting='soft')

# %% [markdown]
# ### Predict

# %%
pred_proba = ensemble_model.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('../../sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./Result/baseline_submit.csv', index=False)

# %%
pred_proba
# Out:
# array([0.00129126, 0.0087868 , 0.15635771, ..., 0.43892084, 0.25794664,
#        0.00402573])

# %%
unique, counts = np.unique(sample_submission['probability'], return_counts=True)
print(unique, counts)
# Out:
# [3.11968470e-04 3.16747788e-04 3.26363115e-04 ... 6.48691944e-01
#  6.49281933e-01 6.62809750e-01] [1 1 1 ... 1 1 1]
