# %% [markdown]
# ### Import

# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import seaborn as sns

# 각 라이브러리 버전 출력
print("Numpy version:", np.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Numpy version: 1.26.4
# Scikit-learn version: 1.5.1
# Pandas version: 1.5.3
# Matplotlib version: 3.9.2
# Seaborn version: 0.13.2

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import  OrdinalEncoder
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# ### Data Load

# %%
import sys
import os
import pandas as pd

# 현재 작업 디렉토리 경로를 가져와 shared codes 폴더의 위치를 sys.path에 추가합니다.
# sys.path에 추가된 경로에 있는 py 폴더는 임포트할 수 있다.
current_dir = os.getcwd()
shared_codes_dir = os.path.join(current_dir, '../shared codes')
sys.path.append(shared_codes_dir)


# cover_nan 모듈을 임포트
from cover_nan import missing_value_removal_function

# 원본 train 데이터 로드
train = pd.read_csv("../shared codes/data/train.csv").drop(columns=['ID'])
test = pd.read_csv("../shared codes/data/test.csv").drop(columns=['ID'])

# missing_value_removal_function 사용
train = missing_value_removal_function(train)
test = missing_value_removal_function(test)
# Out:
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부', '난자 해동 경과일', '배아 해동 경과일']
# ✅ '난자 채취 경과일' 결측값을 중앙값 (0.0) 으로 대체 완료!
# ✅ '난자 혼합 경과일' 결측값을 중앙값 (0.0) 으로 대체 완료!
# ✅ '배아 이식 경과일' 결측값을 중앙값 (3.0) 으로 대체 완료!
# ✅ '대리모 여부' 결측값을 최빈값 (0.0) 으로 대체 완료!
# ✅ 컬럼 삭제 완료: ['PGD 시술 여부', 'PGS 시술 여부', '난자 해동 경과일', '배아 해동 경과일']
# ✅ '난자 채취 경과일' 결측값을 중앙값 (0.0) 으로 대체 완료!
# ✅ '난자 혼합 경과일' 결측값을 중앙값 (0.0) 으로 대체 완료!
# ✅ '배아 이식 경과일' 결측값을 중앙값 (3.0) 으로 대체 완료!

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# %% [markdown]
# ### Data Pre-processing

# %%
columns_fill_zero = [
    # 'PGD 시술 여부', 'PGS 시술 여부',
    '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부'
]
X[columns_fill_zero] = X[columns_fill_zero].fillna(0)
test[columns_fill_zero] = test[columns_fill_zero].fillna(0)

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# Series([], dtype: int64)

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('알 수 없음').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ '알 수 없음' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ⚠️ '알 수 없음' 값을 포함하는 컬럼들:
# ['시술 당시 나이', '배란 유도 유형', '난자 기증자 나이', '정자 기증자 나이']

# %%
# '알 수 없음'이 포함된 열 찾기
unknown_columns = []

for col in X.columns:
    if X[col].astype(str).str.contains('nan').any():
        unknown_columns.append(col)

# 결과 출력
print("⚠️ 'nan' 값을 포함하는 컬럼들:")
print(unknown_columns)
# Out:
# ⚠️ 'nan' 값을 포함하는 컬럼들:
# []

# %%
# NaN 값이 존재하는 컬럼 찾기
unknown_columns = X.columns[X.isna().any()].tolist()

unknown_columns
# Out:
# []

# %%
# Categorical(범주형) 칼럼 찾기
categorical_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()
for col in categorical_columns:
    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

# 결과 출력
print("📌 Categorical(범주형) 칼럼 리스트:")
print(categorical_columns)
# Out:
# 📌 Categorical(범주형) 칼럼 리스트:
# ['시술 시기 코드', '시술 당시 나이', '시술 유형', '특정 시술 유형', '배란 유도 유형', '총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수', 'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '난자 출처', '정자 출처', '난자 기증자 나이', '정자 기증자 나이']

# %%
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

X_train_encoded = X.copy()
X_train_encoded[categorical_columns] = ordinal_encoder.fit_transform(X[categorical_columns])

X_test_encoded = test.copy()
X_test_encoded[categorical_columns] = ordinal_encoder.transform(test[categorical_columns])

# %%
columns_to_drop = [
        "남성 주 불임 원인",
        "남성 부 불임 원인",
        "불임 원인 - 정자 농도",
        "불임 원인 - 정자 면역학적 요인",
        "불임 원인 - 정자 운동성",
        "불임 원인 - 정자 형태",
        '정자 기증자 나이',
        '배란 유도 유형'
]
X_train_encoded = X_train_encoded.drop(columns = columns_to_drop)    
X_test_encoded = X_test_encoded.drop(columns = columns_to_drop)

# %%
# 각 열의 결측값 개수 확인
missing_values_count = X_train_encoded.isnull().sum()

# 결측값이 있는 열만 필터링
missing_columns = missing_values_count[missing_values_count > 0]

print("결측값이 있는 열과 개수:")
print(missing_columns)
# Out:
# 결측값이 있는 열과 개수:
# Series([], dtype: int64)

# %%
X_train_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256351 entries, 0 to 256350
# Data columns (total 54 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   시술 시기 코드          256351 non-null  float64
#  1   시술 당시 나이          256351 non-null  float64
#  2   시술 유형             256351 non-null  float64
#  3   특정 시술 유형          256351 non-null  float64
#  4   배란 자극 여부          256351 non-null  int64
#  5   단일 배아 이식 여부       256351 non-null  float64
#  6   착상 전 유전 검사 사용 여부  256351 non-null  float64
#  7   착상 전 유전 진단 사용 여부  256351 non-null  float64
#  8   여성 주 불임 원인        256351 non-null  int64
#  9   여성 부 불임 원인        256351 non-null  int64
#  10  부부 주 불임 원인        256351 non-null  int64
#  11  부부 부 불임 원인        256351 non-null  int64
#  12  불명확 불임 원인         256351 non-null  int64
#  13  불임 원인 - 난관 질환     256351 non-null  int64
#  14  불임 원인 - 남성 요인     256351 non-null  int64
#  15  불임 원인 - 배란 장애     256351 non-null  int64
#  16  불임 원인 - 여성 요인     256351 non-null  int64
#  17  불임 원인 - 자궁경부 문제   256351 non-null  int64
#  18  불임 원인 - 자궁내막증     256351 non-null  int64
#  19  배아 생성 주요 이유       256351 non-null  int64
#  20  총 시술 횟수           256351 non-null  float64
#  21  클리닉 내 총 시술 횟수     256351 non-null  float64
#  22  IVF 시술 횟수         256351 non-null  float64
#  23  DI 시술 횟수          256351 non-null  float64
#  24  총 임신 횟수           256351 non-null  float64
#  25  IVF 임신 횟수         256351 non-null  float64
#  26  DI 임신 횟수          256351 non-null  float64
#  27  총 출산 횟수           256351 non-null  float64
#  28  IVF 출산 횟수         256351 non-null  float64
#  29  DI 출산 횟수          256351 non-null  float64
#  30  총 생성 배아 수         256351 non-null  float64
#  31  미세주입된 난자 수        256351 non-null  float64
#  32  미세주입에서 생성된 배아 수   256351 non-null  float64
#  33  이식된 배아 수          256351 non-null  float64
#  34  미세주입 배아 이식 수      256351 non-null  float64
#  35  저장된 배아 수          256351 non-null  float64
#  36  미세주입 후 저장된 배아 수   256351 non-null  float64
#  37  해동된 배아 수          256351 non-null  float64
#  38  해동 난자 수           256351 non-null  float64
#  39  수집된 신선 난자 수       256351 non-null  float64
#  40  저장된 신선 난자 수       256351 non-null  float64
#  41  혼합된 난자 수          256351 non-null  float64
#  42  파트너 정자와 혼합된 난자 수  256351 non-null  float64
#  43  기증자 정자와 혼합된 난자 수  256351 non-null  float64
#  44  난자 출처             256351 non-null  float64
#  45  정자 출처             256351 non-null  float64
#  46  난자 기증자 나이         256351 non-null  float64
#  47  동결 배아 사용 여부       256351 non-null  float64
#  48  신선 배아 사용 여부       256351 non-null  float64
#  49  기증 배아 사용 여부       256351 non-null  float64
#  50  대리모 여부            256351 non-null  float64
#  51  난자 채취 경과일         256351 non-null  float64
#  52  난자 혼합 경과일         256351 non-null  float64
#  53  배아 이식 경과일         256351 non-null  float64
# dtypes: float64(41), int64(13)
# memory usage: 105.6 MB

# %%
X_train_encoded['배아 생성 주요 이유'].value_counts()
# Out:
# 1    253108
# 0      3243
# Name: 배아 생성 주요 이유, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 데이터 정규화 (X_train_encoded & X_test_encoded)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)  # 동일한 스케일 적용

# DataFrame 변환 (Feature 이름 유지)
feature_names = [f"Feature_{i}" for i in range(X_train_scaled.shape[1])]
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=feature_names)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=feature_names)

# 상관 행렬 계산
correlation_matrix_train = X_train_scaled_df.corr()

# 다중 공선성이 높은 칼럼 찾기 (절대 상관 계수가 0.8 이상)
threshold = 0.8
high_corr_features = set()

for i in range(len(feature_names)):
    for j in range(i + 1, len(feature_names)):
        if abs(correlation_matrix_train.iloc[i, j]) > threshold:
            high_corr_features.add(feature_names[j])  # 공선성이 높은 컬럼 추가

# 다중 공선성이 높은 컬럼 제거
X_train_encoded = X_train_scaled_df.drop(columns=high_corr_features, errors='ignore')
X_test_encoded = X_test_scaled_df.drop(columns=high_corr_features, errors='ignore')

# %%
X_train_encoded
# Out:
#         Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0        1.518507  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# 1        1.020975   2.655919   0.158613  -0.962962  -1.836376  -0.543057
# 2        0.025910  -0.935575   0.158613   0.672585   0.544551  -0.543057
# 3       -0.471622  -0.217277   0.158613  -0.962962   0.544551  -0.543057
# 4        0.025910  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# ...           ...        ...        ...        ...        ...        ...
# 256346   1.020975  -0.935575   0.158613  -0.962962   0.544551  -0.543057
# 256347   1.020975   0.501022   0.158613  -0.962962   0.544551  -0.543057
# 256348   0.025910  -0.217277   0.158613  -0.962962   0.544551  -0.543057
# 256349   1.518507   0.501022   0.158613  -0.962962   0.544551  -0.543057
# 256350   0.523442  -0.217277   0.158613   0.672585  -1.836376  -0.543057
#
#         Feature_6  Feature_7  Feature_8  Feature_9  ...  Feature_40  \
# 0       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 1       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 2       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 3       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 4       -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# ...           ...        ...        ...        ...  ...         ...
# 256346  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 256347  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 256348  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 256349  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
# 256350  -0.103519   -0.11236  -0.178038  -0.112199  ...   -0.083423
#
#         Feature_43  Feature_44  Feature_45  Feature_47  Feature_49  \
# 0        -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 1        -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 2        -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 3        -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 4        -0.220261    0.256018    0.344047   -0.430784   -0.098393
# ...            ...         ...         ...         ...         ...
# 256346   -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 256347   -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 256348   -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 256349   -0.220261    0.256018    0.344047   -0.430784   -0.098393
# 256350   -0.220261    0.256018    0.344047    2.321347   -0.098393
#
#         Feature_50  Feature_51  Feature_52  Feature_53
# 0          -0.0641         0.0   -0.042922   -0.135020
# 1          -0.0641         0.0   -0.042922   -0.135020
# 2          -0.0641         0.0   -0.042922   -0.773571
# 3          -0.0641         0.0   -0.042922   -0.135020
# 4          -0.0641         0.0   -0.042922   -0.135020
# ...            ...         ...         ...         ...
# 256346     -0.0641         0.0   -0.042922    1.142081
# 256347     -0.0641         0.0   -0.042922   -0.135020
# 256348     -0.0641         0.0   -0.042922   -0.135020
# 256349     -0.0641         0.0   -0.042922   -1.412122
# 256350     -0.0641         0.0   -0.042922   -2.050672
#
# [256351 rows x 43 columns]

# %% [markdown]
# ### Train

# %%
model = ExtraTreesClassifier(random_state=42)

model.fit(X_train_encoded, y)
# Out:
# ExtraTreesClassifier(random_state=42)

# %% [markdown]
# **앙상블 및 Optuna**

# %%
import optuna
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np

# %%
def optimize_xgboost(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5)
    }
    model = XGBClassifier(**params, random_state=42, use_label_encoder=False, eval_metric="logloss")
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")
    return np.mean(scores)

# %%
def optimize_lightgbm(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 10, 50),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0)
    }
    model = LGBMClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
def optimize_random_forest(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_samples_split": trial.suggest_int("min_samples_split", 3, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 4)
    }
    model = RandomForestClassifier(**params, random_state=42)
    scores = cross_val_score(model, X_train_encoded, y, cv=5, scoring="roc_auc")  
    return np.mean(scores)

# %%
# Optuna 스터디 실행
print("Optimizing XGBoost...")
xgb_study = optuna.create_study(direction="maximize")
xgb_study.optimize(optimize_xgboost, n_trials=30)
best_xgb_params = xgb_study.best_params

print("Optimizing LightGBM...")
lgbm_study = optuna.create_study(direction="maximize")
lgbm_study.optimize(optimize_lightgbm, n_trials=30)
best_lgbm_params = lgbm_study.best_params

print("Optimizing RandomForest...")
rf_study = optuna.create_study(direction="maximize")
rf_study.optimize(optimize_random_forest, n_trials=30)
best_rf_params = rf_study.best_params
# Out:
# [I 2025-02-16 17:48:41,753] A new study created in memory with name: no-name-42868755-f6bf-43f3-a191-923697b387be
# Optimizing XGBoost...
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:41] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:43] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:44] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:45] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:48:46,736] Trial 0 finished with value: 0.7344476230135445 and parameters: {'n_estimators': 169, 'max_depth': 12, 'learning_rate': 0.1037292567017286, 'subsample': 0.9985999141248558, 'colsample_bytree': 0.7109952367134122, 'gamma': 1.5700680899884984}. Best is trial 0 with value: 0.7344476230135445.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:46] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:48] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:50] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:51] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:53] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:48:54,837] Trial 1 finished with value: 0.7388725423865397 and parameters: {'n_estimators': 467, 'max_depth': 6, 'learning_rate': 0.11595485917407758, 'subsample': 0.8076572696764857, 'colsample_bytree': 0.7783818617370561, 'gamma': 3.5672096807634297}. Best is trial 1 with value: 0.7388725423865397.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:54] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:56] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:48:58] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:00] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:02] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49:03,708] Trial 2 finished with value: 0.7384378884807319 and parameters: {'n_estimators': 307, 'max_depth': 8, 'learning_rate': 0.043345883477773704, 'subsample': 0.9925020865842937, 'colsample_bytree': 0.9603370773341244, 'gamma': 2.9671754565437096}. Best is trial 1 with value: 0.7388725423865397.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:03] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:05] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:06] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:07] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:08] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49:09,680] Trial 3 finished with value: 0.7390598350395943 and parameters: {'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.07958880193624307, 'subsample': 0.604385151439075, 'colsample_bytree': 0.9832918047022554, 'gamma': 4.778851830770667}. Best is trial 3 with value: 0.7390598350395943.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:09] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:10] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:12] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:14] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:15] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49:16,484] Trial 4 finished with value: 0.7388541811438969 and parameters: {'n_estimators': 315, 'max_depth': 3, 'learning_rate': 0.21186020202221437, 'subsample': 0.9144131682475276, 'colsample_bytree': 0.8789949880853061, 'gamma': 1.90699359264198}. Best is trial 3 with value: 0.7390598350395943.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:16] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:17] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:19] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:20] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:22] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49:23,757] Trial 5 finished with value: 0.738496310057591 and parameters: {'n_estimators': 421, 'max_depth': 3, 'learning_rate': 0.20626291129723562, 'subsample': 0.6803946585002709, 'colsample_bytree': 0.9261728910536576, 'gamma': 3.072726411234572}. Best is trial 3 with value: 0.7390598350395943.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:23] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:24] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:26] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:27] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:28] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49:29,186] Trial 6 finished with value: 0.7359277216105357 and parameters: {'n_estimators': 221, 'max_depth': 10, 'learning_rate': 0.10142096854009108, 'subsample': 0.6710787003828043, 'colsample_bytree': 0.8589273269303876, 'gamma': 2.5593135240558023}. Best is trial 3 with value: 0.7390598350395943.
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:29] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:30] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:32] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:33] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [17:49:35] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-16 17:49
 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:29:31,338] Trial 21 finished with value: 0.7345866922485682 and parameters: {'n_estimators': 279, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:31:45,267] Trial 22 finished with value: 0.7345796859140813 and parameters: {'n_estimators': 259, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:33:33,229] Trial 23 finished with value: 0.733716517576928 and parameters: {'n_estimators': 221, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:36:00,457] Trial 24 finished with value: 0.7345510186080684 and parameters: {'n_estimators': 285, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:38:08,539] Trial 25 finished with value: 0.732776550411146 and parameters: {'n_estimators': 281, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:40:12,136] Trial 26 finished with value: 0.7339261385484346 and parameters: {'n_estimators': 252, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:41:26,017] Trial 27 finished with value: 0.7296754079565456 and parameters: {'n_estimators': 191, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 16 with value: 0.7346912200626394.
# [I 2025-02-16 18:43:29,965] Trial 28 finished with value: 0.7347017321306286 and parameters: {'n_estimators': 243, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 28 with value: 0.7347017321306286.
# [I 2025-02-16 18:45:30,101] Trial 29 finished with value: 0.7338369038956676 and parameters: {'n_estimators': 239, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 28 with value: 0.7347017321306286.

# %%
# 최적화된 모델 생성
xgb_model = XGBClassifier(**best_xgb_params, random_state=42, use_label_encoder=False, eval_metric="logloss")
lgbm_model = LGBMClassifier(**best_lgbm_params, random_state=42)
rf_model = RandomForestClassifier(**best_rf_params, random_state=42)

# %%
# XGBoost 모델의 파라미터 확인
print("XGBoost Best Parameters:")
print(xgb_model.get_params())

# LightGBM 모델의 파라미터 확인
print("\nLightGBM Best Parameters:")
print(lgbm_model.get_params())

# RandomForest 모델의 파라미터 확인
print("\nRandomForest Best Parameters:")
print(rf_model.get_params())
# Out:
# XGBoost Best Parameters:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.7167659459131764, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': 'logloss', 'feature_types': None, 'gamma': 3.654050896673531, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.07767196749651278, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 272, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8659580387601626, 'tree_method': None, 'validate_parameters': None, 'verbosity': None, 'use_label_encoder': False}
#
# LightGBM Best Parameters:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.049641266967959286, 'max_depth': 8, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 202, 'n_jobs': None, 'num_leaves': 20, 'objective': None, 'random_state': 42, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8627223243612347, 'subsample_for_bin': 200000, 'subsample_freq': 0}
#
# RandomForest Best Parameters:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 12, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 8, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 243, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
# Soft Voting 앙상블
ensemble_model = VotingClassifier(
    estimators=[
        ("xgb", xgb_model),
        ("lgbm", lgbm_model),
        ("rf", rf_model)
    ],
    voting="soft"
)

# %%
# 전체 데이터로 학습
ensemble_model.fit(X_train_encoded, y)
# Out:
# c:\Users\hoyeong\anaconda3\envs\lg_ai\lib\site-packages\xgboost\core.py:158: UserWarning: [18:45:30] WARNING: D:\bld\xgboost-split_1722454234704\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 66228, number of negative: 190123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 509
# [LightGBM] [Info] Number of data points in the train set: 256351, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054568
# [LightGBM] [Info] Start training from score -1.054568
# VotingClassifier(estimators=[('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.7167659459131764,
#                                             device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None,
#                                             gamma=3.654050896673531,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interact...
#                                             n_estimators=272, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=42, ...)),
#                              ('lgbm',
#                               LGBMClassifier(learning_rate=0.049641266967959286,
#                                              max_depth=8, n_estimators=202,
#                                              num_leaves=20, random_state=42,
#                                              subsample=0.8627223243612347)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=12,
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=8,
#                                                      n_estimators=243,
#                                                      random_state=42))],
#                  voting='soft')

# %% [markdown]
# ### Predict

# %%
pred_proba = ensemble_model.predict_proba(X_test_encoded)[:, 1]

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('../../sample_submission.csv')
sample_submission['probability'] = pred_proba

# %%
sample_submission.to_csv('./Result/baseline_submit.csv', index=False)

# %%
pred_proba
# Out:
# array([0.01523793, 0.01216065, 0.15930585, ..., 0.44774629, 0.24253954,
#        0.00899354])

# %%
unique, counts = np.unique(sample_submission['probability'], return_counts=True)
print(unique, counts)
# Out:
# [3.12517455e-04 3.19794711e-04 3.20597598e-04 ... 6.64840012e-01
#  6.67096940e-01 6.68309265e-01] [1 1 1 ... 1 1 1]
